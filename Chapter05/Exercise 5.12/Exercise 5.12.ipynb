# %%
# !pip install openpyxl
# Out:
# Requirement already satisfied: openpyxl in /opt/anaconda3/lib/python3.12/site-packages (3.1.5)
# Requirement already satisfied: et-xmlfile in /opt/anaconda3/lib/python3.12/site-packages (from openpyxl) (1.1.0)

# %%
import pandas as pd
from bs4 import BeautifulSoup
fd = open("../datasets/test.html", "r")
soup = BeautifulSoup(fd)
data = soup.findAll('tr')

# %%
data_without_header = data[1:]
headers = data[0]

# %%
col_headers = [th.getText() for th in headers.findAll('th')]

# %%
df_data = [[td.getText() for td in tr.findAll('td')] for tr in data_without_header]

# %%
df = pd.DataFrame(df_data, columns=col_headers)

# %%
import pandas as pd
writer = pd.ExcelWriter('../datasets/test_output.xlsx') 
df.to_excel(writer, "Sheet1") 
writer
# Out:
# /var/folders/7m/thkwcjl55fjbbvhp8fxff96w0000gn/T/ipykernel_57881/2527562714.py:3: FutureWarning: Starting with pandas version 3.0 all arguments of to_excel except for the argument 'excel_writer' will be keyword-only.
#   df.to_excel(writer, "Sheet1")
