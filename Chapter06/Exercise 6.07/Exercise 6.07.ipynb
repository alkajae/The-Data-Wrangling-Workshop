# %%
from math import cos, pi
ys = [cos(i*(pi/4)) for i in range(50)]

# %%
import matplotlib.pyplot as plt 
# %matplotlib inline 
plt.plot(ys)
plt.show()

# %%
ys[4] = ys[4] + 5.0
ys[20] = ys[20] + 8.0

# %%
plt.plot(ys)

# %%
plt.boxplot(ys)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x11bbe70b0>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x11bbf9ca0>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x11bbe4470>],
#  'medians': [<matplotlib.lines.Line2D at 0x11bbfae10>],
#  'fliers': [<matplotlib.lines.Line2D at 0x11bbfb110>],
#  'means': []}
